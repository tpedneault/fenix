# %% [markdown]
# # {{name}}
#
# Put a file in `data/raw/` and start here.

# %%
from {{name_snake}}.io import RAW, load

files = sorted(p for p in RAW.iterdir() if p.is_file() and not p.name.startswith("."))
frame = load(files[0]) if files else None
frame
